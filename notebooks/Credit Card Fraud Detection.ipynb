# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE, ADASYN
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import metodos as m
import SVM as s

# %matplotlib inline

# %%
data = pd.read_csv('../data/creditcard.csv')

# %%
print(data.shape)
print('Cantidad de registros: ', len(data))
data.head()
# Out:
# (284807, 31)
# Cantidad de registros:  284807
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
print('Número de filas: ', data.shape[0])
print('Número de columnas: ', data.shape[1])
print('Nombres de las columnas: ', data.columns.values.tolist())
print('Tipos de datos: ', data.dtypes)
# Out:
# Número de filas:  284807
# Número de columnas:  31
# Nombres de las columnas:  ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']
# Tipos de datos:  Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
print('Número de columnas con datos nulos: ', data.columns[data.isnull().any()].tolist())
print('Número de filas con datos nulos:', len(pd.isnull(data).any(1).nonzero()[0].tolist()))
# Out:
# Número de columnas con datos nulos:  []
# Número de filas con datos nulos: 0

# %%
x = data.drop(['Class'], axis=1)
y = data['Class']

# %%
counts = y.value_counts()
num_tv = counts[0]
num_tf = counts[1]

m.MostrarProporciones(num_tv, num_tf)
# Out:
# Cantidad de transacciónes válidas: 284315
# Cantidad de transacciónes fraudulentas: 492
# Grado de desbalanceamiento: 0.0017304750013189597

# %%
data[data['Class'] == 0].Amount.hist(color='green', bins=100)
plt.yscale('log')
plt.title('Histograma con escala logaritmica de transacciones válidas por Cantidad')
plt.show()

# %%
data[data['Class'] == 1].Amount.hist(color='green')
plt.title('Histograma de Cantidades transacciones fraudulentas')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=0)

# Obtener hiper parametros afinados utilizando GridSearch (SVC)
parametros_svc = s.ObtenerHiperParametros(x_train, y_train, x_test, y_test)
print(parametros_svc)

# Obtener hiper parametros afinados utilizando GridSearch (KNN)

# Obtener hiper parametros afinados utilizando GridSearch (Bayes)

# Obtener hiper parametros afinados utilizando GridSearch (RandomForest)

# Clasificador Linear SVC
clf1 = s.Entrenar(x_train, y_train, parametros_svc)
m.MostrarMatrizDeConfusion(clf1, x_test, y_test)

# Clasificador KNN

# Clasificador Bayes

# Clasificador RandomForest
# Out:
# {'C': 1, 'class_weight': {1: 5}, 'dual': False, 'penalty': 'l1'}
#               +-----------------+
#               |   Predicción    |
#               +-----------------+
#               |    +   |    -   |
# +-------+-----+--------+--------+
# | Valor |  +  |   44 |   11   |
# | real  +-----+--------+--------+
# |       |  -  |   6  |   28420  |
# +-------+-----+--------+--------+
#
# Exactitud        :  0.999403110845827
# Precición        :  0.88
# Exhaustividad    :  0.8

# %%
#Añadir probabilidades para KNN, Bayes y RandomForest
predicciones_base_test = pd.concat([pd.DataFrame(clf1._predict_proba_lr(x_test))],axis=1)

#Añadir columnas para KNN, Bayes y RandomForest
predicciones_base_test.columns = ['svm-valido', 'svm-fraude']

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

mejor_score = 0
mejor_C = None

for C in np.logspace(-2,4,13):  # ~ [0.01, 0.03, 0.1, ..., 10000] 
    ensamble = LogisticRegression(penalty='l2', C=C, random_state=0)
    ensamble.fit(predicciones_base_test, y_test)
    scores_val = m.ObtenerMedidaDeCalidad(ensamble, predicciones_base_test, y_test)
    score_val_medio = np.mean(scores_val)
    if score_val_medio > mejor_score: 
        mejor_score = score_val_medio
        mejor_C = C

# Habiendo obtenido el mejor C, ajustar el modelo con todo el conjunto de entrenamiento
ensamble = LogisticRegression(penalty='l2', C=mejor_C, random_state=0)
ensamble.fit(predicciones_base_test, y_test)

print ("Rendimiento en el conjunto de entrenamiento")
print ("-------------------------------------------")
print ("Área bajo la curva de Presición/Exhaustividad del modelo de SVM Linear           :", m.ObtenerMedidaDeCalidad(clf1, x_test, y_test))
# Clasificador KNN
# Clasificador Bayes
# Clasificador RandomForest
print ("Área bajo la curva de Presición/Exhaustividad del modelo por regresión logística :", m.ObtenerMedidaDeCalidad(ensamble, predicciones_base_test, y_test))
# Out:
# Rendimiento en el conjunto de entrenamiento
# -------------------------------------------
# Área bajo la curva de Presición/Exhaustividad del modelo de SVM Linear           : 0.8375182650160207
# Área bajo la curva de Presición/Exhaustividad del modelo por regresión logística : 0.8375182650160207
